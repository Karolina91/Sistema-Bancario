# %% [markdown]
# <a href="https://colab.research.google.com/github/Karolina91/Sistema-Bancario/blob/main/Projeto3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

# %% [markdown]
# ##**Classe BancoDados**

# %%
import csv

class BancoDados:
    def __init__(self, nome_arquivo):
        self.nome_arquivo = nome_arquivo

    def carregar_clientes(self):
        clientes = []
        with open(self.nome_arquivo, newline='') as file:
            reader = csv.DictReader(file)
            for row in reader:
                clientes.append(row)
        return clientes

    def salvar_clientes(self, clientes):
        with open(self.nome_arquivo, 'w', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=clientes[0].keys())
            writer.writeheader()
            writer.writerows(clientes)

    def cadastrar_cliente(self, cliente):
        with open(self.nome_arquivo, 'w', newline='') as file:
          writer = csv.writer(file)
          writer.writerow([nome, email, telefone, cpf, endereço])

    def remover_cliente(self, cliente):
        with open (self.nome_arquivo, 'r') as file:
          linhas=list (csv.read(file))
          with open (self.nome_arquivo, 'w', newline='') as file:
            writer=csv.writer(file)
            for linha in linha:
              if linha[0]! = senha
              writer.writerow(linha)

    def editar_cliente(self, cliente, novo_nome):
      with open(" clientes.csv", "r") as file
      linhas=list (csv.reader(file))
      for linha in linhas:
        if linha[0]== str (cliente_senha):
          linha[1]= novo_nome
          linha[2]= novo_email
          break
        with open("clientes.csv", "w", newline="") as file:
          writer=csv.writer(file)
          writer.writerow(linhas)


    def cliente_existe(self, cpf_cnpj):
        pass

# %% [markdown]
# ##**Classe Pessoa**

# %%
class Pessoa:
    def __init__(self, nome, cpf_cnpj, endereco, telefone, senha):
        self.nome = nome
        self.cpf_cnpj = cpf_cnpj
        self.endereco = endereco
        self.telefone = telefone
        self.senha = senha

# %% [markdown]
# ###**Classe Cliente**

# %%
class Cliente(Pessoa):
    def __init__(self, nome, cpf_cnpj, endereco, telefone, senha, saldo):
        super().__init__(nome, cpf_cnpj, endereco, telefone, senha)
        self.saldo = saldo
        self.historico = []

    def realizar_saque(self, valor):
        if valor <= self.saldo:
            self.saldo -= valor
            self.historico.append(f"Saque: R${valor}")
            print(f"Saque de R${valor} realizado com sucesso.")
        else:
            print("Saldo insuficiente.")

    def realizar_deposito(self, valor):
        if valor > 0:
            self.saldo += valor
            self.historico.append(f"Depósito: R${valor}")
            print(f"Depósito de R${valor} realizado com sucesso.")
        else:
            print("Valor de depósito inválido.")

    def realizar_pagamento_programado(self, valor):
        pass
#falta lógica

    def verificar_historico(self):
        pass
#falta lógica

    def solicitar_credito(self, valor):
        pass
#falta lógica

# %% [markdown]
# ###**Classe Gerente**

# %%
class Gerente(Pessoa):
    def __init__(self, nome, cpf_cnpj, endereco, telefone, senha):
        super().__init__(nome, cpf_cnpj, endereco, telefone, senha)

    def cadastrar_cliente(self, clientes, cliente):
        nome= input("Digite o nome do cliente: ")
        cpf_cnpj= input("Digite o CPF/CNPJ do cliente: ")
        endereco= input("Digite o endereço do cliente: ")
        telefone= input("Digite o telefone do cliente: ")
        senha= input("Digite a senha do cliente:")
        cliente = {"nome"= nome, "cpf_cnpj"= cpf_cnpj, "endereco"= endereco, "telefone"= telefone, "senha"= senha}
        with open ("clientes.csv", "a", newline="") as file:
          writer.writerow(clientes.values())
          print('Cliente cadastrado com sucesso.')

    def remover_cliente(self, clientes, cliente):
        pass
#falta lógica

    def editar_cliente(self, cliente, novo_nome):
       pass
#falta lógica

    def visualizar_clientes(self, clientes):
        pass
#falta lógica

# %% [markdown]
# ##**Classe CaixaAutomatico**

# %%
class CaixaEletronico:
    def __init__(self):
       pass
#falta lógica
    def realizar_saque(self):
        pass
#falta lógica

    def realizar_deposito(self):
        pass
#falta lógica

    def realizar_pagamento_programado(self):
        pass
#falta lógica

    def verificar_historico(self):
        pass
#falta lógica

    def solicitar_credito(self):
        pass
#falta lógica

def exibir_menu():
    print("Selecione uma opção:")
    print("1. Saque")
    print("2. Depósito")
    print("3. Pagamento Programado")
    print("4. Verificar Histórico")
    print("5. Solicitar Crédito")
    print("0. Sair")

def cadastrar_novo_cliente():
    nome = input("Nome: ")
    cpf_cnpj = input("CPF/CNPJ: ")
    endereco = input("Endereço: ")
    telefone = input("Telefone (no formato 61-99999-9999): ")
    senha = input("Senha (6 dígitos numéricos): ")
    saldo = float(input("Saldo inicial: "))
    novo_cliente = {
        'Id_cliente': int(len('id_cliente') + 1),
        'Nome': nome,
        'Endereço': endereco,
        'Saldo': str(saldo),
        'Telefone': telefone,
        'Senha': senha,
        'Histórico': ''
    }
    return novo_cliente



def main():
    # Simulação de dados de clientes para testes
    clientes = [
        {
            'Id_cliente': '1',
            'CPF/CNPJ': '32365498803',
            'Nome': 'João',
            'Endereço': 'Rua A, 123',
            'Saldo': '1000',
            'Telefone': '61-99999-9999',
            'Senha': '123456',
            'Histórico': ''
        },
        {
            'Id_cliente': '2',
            'CPF/CNPJ': '12365498803',
            'Nome': 'Maria',
            'Endereço': 'Rua B, 456',
            'Saldo': '2000',
            'Telefone': '61-88888-8888',
            'Senha': '654321',
            'Histórico': ''
        }
    ]


    banco_dados = BancoDados('clientes.csv')
    banco_dados.salvar_clientes(clientes)

    # Simulação de login
    cpf_cnpj = input("Digite o seu CPF/CNPJ: ")
    senha = input("Digite a sua senha: ")

    # Verificar se é gerente ou cliente
    if cpf_cnpj == 'gerente' and senha == 'gerente':
        gerente = Gerente("Gerente", cpf_cnpj, "", "", "")
        gerente.visualizar_clientes(clientes)
        # Lógica para gerente
    else:
        # Lógica para cliente
        cliente = None
        for c in clientes:
            if c['CPF/CNPJ'] == cpf_cnpj and c['Senha'] == senha:
                cliente = Cliente(c['Nome'], c['CPF/CNPJ'], c['Endereço'], c['Telefone'], c['Senha'], float(c['Saldo']))
                break

        #cadastrar novo cliente se ele não estiver no arquivo de dados
        if cliente is None:
            opcao_cadastro = input("CPF/CNPJ não encontrado. Deseja cadastrar um novo cliente? (sim ou nao): ")
            if opcao_cadastro.lower() == 'sim':
                novo_cliente = cadastrar_novo_cliente()
                banco_dados.cadastrar_cliente(novo_cliente)
                clientes = banco_dados.carregar_clientes()
            else:
                print("Encerrando o programa.")
                return

            caixa_eletronico = CaixaEletronico(cliente)
            while True:
                exibir_menu()
                opcao = input("Opção: ")

                if opcao == '0':
                    break
                elif opcao == '1':
                    valor = float(input("Digite o valor do saque: "))
                    caixa_eletronico.realizar_saque(valor)
                elif opcao == '2':
                    valor = float(input("Digite o valor do depósito: "))
                    caixa_eletronico.realizar_deposito(valor)
                elif opcao == '3':
                    valor = float(input("Digite o valor do pagamento programado: "))
                    caixa_eletronico.realizar_pagamento_programado(valor)
                elif opcao == '4':
                    caixa_eletronico.verificar_historico()
                elif opcao == '5':
                    valor = float(input("Digite o valor do crédito: "))
                    caixa_eletronico.solicitar_credito(valor)
                else:
                    print("Opção inválida.")

    banco_dados.salvar_clientes(clientes)

if __name__ == "__main__":
    main()
# Out:
# Digite o seu CPF/CNPJ: 02882521103
# Digite a sua senha: 012345
# CPF/CNPJ não encontrado. Deseja cadastrar um novo cliente? (S/N): S
# Nome: juliana
# CPF/CNPJ: 02882521103
# Endereço: guara
# Telefone (no formato 61-99999-9999): 61-983354681
# Senha (6 dígitos numéricos): 074125
# Saldo inicial: 10000
# Selecione uma opção:
# 1. Saque
# 2. Depósito
# 3. Pagamento Programado
# 4. Verificar Histórico
# 5. Solicitar Crédito
# 0. Sair
# Opção: 2
# Digite o valor do depósito: 300
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3780b505cf1a> in <cell line: 131>()
#     130
#     131 if __name__ == "__main__":
# --> 132     main()
#
# <ipython-input-7-3780b505cf1a> in main()
#     115                 elif opcao == '2':
#     116                     valor = float(input("Digite o valor do depósito: "))
# --> 117                     caixa_eletronico.realizar_deposito(valor)
#     118                 elif opcao == '3':
#     119                     valor = float(input("Digite o valor do pagamento programado: "))
#
# <ipython-input-7-3780b505cf1a> in realizar_deposito(self, valor)
#       7
#       8     def realizar_deposito(self, valor):
# ----> 9         self.cliente.realizar_deposito(valor)
#      10
#      11     def realizar_pagamento_programado(self, valor):
#
# AttributeError: 'NoneType' object has no attribute 'realizar_deposito'

# %% [markdown]
# #**Codigo Pronto**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

class Pessoa:
    def __init__(self, nome, cpf_cnpj, endereco, telefone, senha):
        self.nome = nome
        self.cpf_cnpj = cpf_cnpj
        self.endereco = endereco
        self.telefone = telefone
        self.senha = senha

class Cliente(Pessoa):
    def __init__(self, nome, cpf_cnpj, endereco, telefone, senha, saldo):
        super().__init__(nome, cpf_cnpj, endereco, telefone, senha)
        self.saldo = saldo
        self.historico = []

    def realizar_saque(self, valor):
        if valor <= self.saldo:
            self.saldo -= valor
            self.historico.append(f"Saque: R${valor}")
            print(f"Saque de R${valor} realizado com sucesso.")
        else:
            print("Saldo insuficiente.")

    def realizar_deposito(self, valor):
        if valor > 0:
            self.saldo += valor
            self.historico.append(f"Depósito: R${valor}")
            print(f"Depósito de R${valor} realizado com sucesso.")
        else:
            print("Valor de depósito inválido.")

    def realizar_pagamento_programado(self, valor):
        if valor <= self.saldo:
            self.saldo -= valor
            self.historico.append(f"Pagamento Programado: R${valor}")
            print(f"Pagamento programado de R${valor} realizado com sucesso.")
        else:
            print("Saldo insuficiente para realizar o pagamento programado.")

    def verificar_historico(self):
        print("Histórico de ações:")
        for acao in self.historico:
            print(acao)

    def solicitar_credito(self, valor):
        if valor > 0:
            self.historico.append(f"Solicitação de Crédito: R${valor}")
            print(f"Solicitação de crédito de R${valor} realizada com sucesso. Será debitado em datas programadas.")
        else:
            print("Valor de crédito inválido.")

class Gerente(Pessoa):
    def __init__(self, nome, cpf_cnpj, endereco, telefone, senha):
        super().__init__(nome, cpf_cnpj, endereco, telefone, senha)

    def cadastrar_cliente(self, clientes, cliente):
        clientes.append(cliente)
        print("Cliente cadastrado com sucesso.")

    def remover_cliente(self, clientes, cliente):
        clientes.remove(cliente)
        print("Cliente removido com sucesso.")

    def editar_cliente(self, cliente, novo_nome):
        cliente.nome = novo_nome
        print("Cliente editado com sucesso.")

    def visualizar_clientes(self, clientes):
        print("Lista de clientes:")
        for cliente in clientes:
            print(cliente.nome)

class BancoDados:
    def __init__(self, nome_arquivo):
        self.nome_arquivo = nome_arquivo

    def carregar_clientes(self):
        clientes = []
        with open(self.nome_arquivo, newline='') as file:
            reader = csv.DictReader(file)
            for row in reader:
                clientes.append(row)
        return clientes

    def salvar_clientes(self, clientes):
        with open(self.nome_arquivo, 'w', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=clientes[0].keys())
            writer.writeheader()
            writer.writerows(clientes)

    def cadastrar_cliente(self, cliente):
        clientes = self.carregar_clientes()
        clientes.append(cliente)
        self.salvar_clientes(clientes)

    def cliente_existe(self, cpf_cnpj):
        clientes = self.carregar_clientes()
        for cliente in clientes:
            if cliente['CPF/CNPJ'] == cpf_cnpj:
                return True
        return False

def exibir_menu():
    print("----- Menu de Opções -----")
    print("0 - Sair")
    print("1 - Realizar Saque")
    print("2 - Realizar Depósito")
    print("3 - Realizar Pagamento Programado")
    print("4 - Verificar Histórico")
    print("5 - Solicitar Crédito")

def cadastrar_novo_cliente():
    nome = input("Nome: ")
    cpf_cnpj = input("CPF/CNPJ: ")
    endereco = input("Endereço: ")
    telefone = input("Telefone: ")
    senha = int(input("Senha: "))
    saldo = float(input("Saldo inicial: "))

    return {'Nome': nome, 'CPF/CNPJ': cpf_cnpj, 'Endereço': endereco,
            'Telefone': telefone, 'Senha': senha, 'Saldo': saldo}

class CaixaEletronico:
    def __init__(self, cliente):
        self.cliente = cliente

    def realizar_saque(self, valor):
        if self.cliente.saldo >= valor:
            self.cliente.saldo -= valor
            self.cliente.historico.append(f"Saque: -{valor}")
            print("Saque realizado com sucesso.")
        else:
            print("Saldo insuficiente.")

    def realizar_deposito(self, valor):
        self.cliente.saldo += valor
        self.cliente.historico.append(f"Depósito: +{valor}")
        print("Depósito realizado com sucesso.")

    def realizar_pagamento_programado(self, valor):
        if self.cliente.saldo >= valor:
            self.cliente.saldo -= valor
            self.cliente.historico.append(f"Pagamento Programado: -{valor}")
            print("Pagamento programado realizado com sucesso.")
        else:
            print("Saldo insuficiente.")

    def verificar_historico(self):
        print("Histórico de transações:")
        for transacao in self.cliente.historico:
            print(transacao)

    def solicitar_credito(self, valor):
        if valor > 0:
            self.cliente.saldo += valor
            self.cliente.historico.append(f"Solicitação de Crédito: +{valor}")
            print("Solicitação de crédito realizada com sucesso.")
        else:
            print("Valor inválido para solicitação de crédito.")

def main():
    cliente = '/content/drive/MyDrive/DataSetATM/clientes.csv'
    banco_dados = BancoDados(cliente)
    clientes = banco_dados.carregar_clientes()

    while True:
        print("Sistema Bancário")
        print("1 - Realizar Login")
        print("2 - Cadastrar Novo Cliente")
        print("0 - Sair")

        opcao = input("Opção: ")

        if opcao == '1':
            cpf_cnpj = input("CPF/CNPJ: ")
            senha = int(input("Senha: "))

            cliente_encontrado = None
            for cliente in clientes:
                if cliente['CPF/CNPJ'] == cpf_cnpj and int(cliente['Senha']) == senha:
                    cliente_encontrado = cliente
                    break

            if cliente_encontrado:
                cliente = Cliente(cliente_encontrado['Nome'], cliente_encontrado['CPF/CNPJ'],
                                  cliente_encontrado['Endereço'], cliente_encontrado['Telefone'],
                                  int(cliente_encontrado['Senha']), float(cliente_encontrado['Saldo']))
                caixa_eletronico = CaixaEletronico(cliente)

                while True:
                    exibir_menu()
                    opcao = input("Opção: ")

                    if opcao == '0':
                        break
                    elif opcao == '1':
                        valor = float(input("Digite o valor do saque: "))
                        caixa_eletronico.realizar_saque(valor)
                    elif opcao == '2':
                        valor = float(input("Digite o valor do depósito: "))
                        caixa_eletronico.realizar_deposito(valor)
                    elif opcao == '3':
                        valor = float(input("Digite o valor do pagamento programado: "))
                        caixa_eletronico.realizar_pagamento_programado(valor)
                    elif opcao == '4':
                        caixa_eletronico.verificar_historico()
                    elif opcao == '5':
                        valor = float(input("Digite o valor do crédito: "))
                        caixa_eletronico.solicitar_credito(valor)
                    else:
                        print("Opção inválida.")

            else:
                print("CPF/CNPJ ou senha inválidos.")

        elif opcao == '2':
            novo_cliente = cadastrar_novo_cliente()
            if banco_dados.cliente_existe(novo_cliente['CPF/CNPJ']):
                print("Cliente já cadastrado.")
            else:
                banco_dados.cadastrar_cliente(novo_cliente)
                clientes = banco_dados.carregar_clientes()
                cliente = Cliente(novo_cliente['Nome'], novo_cliente['CPF/CNPJ'], novo_cliente['Endereço'],
                                  novo_cliente['Telefone'], int(novo_cliente['Senha']), float(novo_cliente['Saldo']))
                caixa_eletronico = CaixaEletronico(cliente)

                while True:
                    exibir_menu()
                    opcao = input("Opção: ")

                    if opcao == '0':
                        break
                    elif opcao == '1':
                        valor = float(input("Digite o valor do saque: "))
                        caixa_eletronico.realizar_saque(valor)
                    elif opcao == '2':
                        valor = float(input("Digite o valor do depósito: "))
                        caixa_eletronico.realizar_deposito(valor)
                    elif opcao == '3':
                        valor = float(input("Digite o valor do pagamento programado: "))
                        caixa_eletronico.realizar_pagamento_programado(valor)
                    elif opcao == '4':
                        caixa_eletronico.verificar_historico()
                    elif opcao == '5':
                        valor = float(input("Digite o valor do crédito: "))
                        caixa_eletronico.solicitar_credito(valor)
                    else:
                        print("Opção inválida.")

        elif opcao == '0':
            break
        else:
            print("Opção inválida.")

if __name__ == '__main__':
    main()
# Out:
# Sistema Bancário
# 1 - Realizar Login
# 2 - Cadastrar Novo Cliente
# 0 - Sair
# Opção: 1
# CPF/CNPJ: 07445898805
# Senha: 7890321
# ----- Menu de Opções -----
# 0 - Sair
# 1 - Realizar Saque
# 2 - Realizar Depósito
# 3 - Realizar Pagamento Programado
# 4 - Verificar Histórico
# 5 - Solicitar Crédito
# Opção: 2
# Digite o valor do depósito: 3000
# Depósito realizado com sucesso.
# ----- Menu de Opções -----
# 0 - Sair
# 1 - Realizar Saque
# 2 - Realizar Depósito
# 3 - Realizar Pagamento Programado
# 4 - Verificar Histórico
# 5 - Solicitar Crédito
# Opção: 1
# Digite o valor do saque: 700
# Saque realizado com sucesso.
# ----- Menu de Opções -----
# 0 - Sair
# 1 - Realizar Saque
# 2 - Realizar Depósito
# 3 - Realizar Pagamento Programado
# 4 - Verificar Histórico
# 5 - Solicitar Crédito
# Opção: 5
# Digite o valor do crédito: 130
# Solicitação de crédito realizada com sucesso.
# ----- Menu de Opções -----
# 0 - Sair
# 1 - Realizar Saque
# 2 - Realizar Depósito
# 3 - Realizar Pagamento Programado
# 4 - Verificar Histórico
# 5 - Solicitar Crédito
# Opção: 3
# Digite o valor do pagamento programado: 40
# Pagamento programado realizado com sucesso.
# ----- Menu de Opções -----
# 0 - Sair
# 1 - Realizar Saque
# 2 - Realizar Depósito
# 3 - Realizar Pagamento Programado
# 4 - Verificar Histórico
# 5 - Solicitar Crédito
# Opção: 4
# Histórico de transações:
# Depósito: +3000.0
# Saque: -700.0
# Solicitação de Crédito: +130.0
# Pagamento Programado: -40.0
# ----- Menu de Opções -----
# 0 - Sair
# 1 - Realizar Saque
# 2 - Realizar Depósito
# 3 - Realizar Pagamento Programado
# 4 - Verificar Histórico
# 5 - Solicitar Crédito
# Opção: 0
# Sistema Bancário
# 1 - Realizar Login
# 2 - Cadastrar Novo Cliente
# 0 - Sair
# Opção: 0
